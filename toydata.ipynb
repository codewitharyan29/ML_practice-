# %% [markdown]
# <a href="https://colab.research.google.com/github/codewitharyan29/ML_practice-/blob/main/toydata.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('placement.csv')
print(df.head())
# Out:
#    Unnamed: 0  cgpa     iq  placement
# 0           0   6.8  123.0          1
# 1           1   5.9  106.0          0
# 2           2   5.3  121.0          0
# 3           3   7.4  132.0          1
# 4           4   5.8  142.0          0

# %%
X=df.iloc[:,:2]
y=df.iloc[:,-1]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=4)

# %%
from sklearn.preprocessing import StandardScaler
cst=StandardScaler()
X_train=cst.fit_transform(X_train)
X_test=cst.transform(X_test)

# %%
from sklearn.linear_model import LogisticRegression
model=LogisticRegression()
model.fit(X_train,y_train)
y_pred=model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score
print(f"accuracy:{accuracy_score(y_test,y_pred)}")
# Out:
# accuracy:0.95

# %%
NEW_STUDENT=np.array([[0,10]])
new_scale_transform=cst.transform(NEW_STUDENT)
PREDICTION=model.predict(new_scale_transform)
print(PREDICTION)
# Out:
# [1]
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
